# %%
import numpy as np
import pandas as pd
from icecream import ic
from IPython.display import clear_output

from tqdm import tqdm
import time
from nba_api.stats.endpoints import (
    boxscoreadvancedv3,
    boxscoretraditionalv2,
    boxscoretraditionalv3,
    boxscorefourfactorsv3,
    boxscorehustlev2,
    boxscoremiscv3,
    boxscoreplayertrackv3,
    boxscorescoringv3,
    leaguegamelog,
    leaguedashplayerstats,
    leaguedashteamstats,
)
from tenacity import retry, stop_after_attempt, wait_fixed

pd.options.mode.chained_assignment =  None

box_DIR = "../../data/box/"
shiny_DIR = "../../data/shiny/"

# %%
import requests
from nba_api.stats.library.http import NBAStatsHTTP

# %%
boxscores = [
    {
        "name": "Trad",
        "fun": boxscoretraditionalv3.BoxScoreTraditionalV3,
    },
    {
        "name": "Adv",
        "fun": boxscoreadvancedv3.BoxScoreAdvancedV3,
    },
    {
        "name": "4Factor",
        "fun": boxscorefourfactorsv3.BoxScoreFourFactorsV3,
    },
    {
        "name": "Misc",
        "fun": boxscoremiscv3.BoxScoreMiscV3,
    },
    {
        "name": "Scoring", 
        "fun": boxscorescoringv3.BoxScoreScoringV3
    },
    {
        "name": "Track",
        "fun": boxscoreplayertrackv3.BoxScorePlayerTrackV3,
    },
    {
        "name": "Hustle",
        "fun": boxscorehustlev2.BoxScoreHustleV2,
    },
]

# %%
def get_gameids(season, name):
    df = pd.read_parquet(
        box_DIR + "NBA_Box_T_" + "Base" + "_" + season + ".parquet"
    )
    game_ids1 = df["GAME_ID"].tolist()
    game_ids1 = np.unique(game_ids1)
    try:
        dfr1 = pd.read_parquet(
            box_DIR + "NBA_Box_T_" + name + "_" + season + ".parquet1"
        )
        dfr2 = pd.read_parquet(
            box_DIR + "NBA_Box_P_" + name + "_" + season + ".parquet"
        )
        game_ids3 = dfr1["gameId"].tolist()
        game_ids2 = np.unique(game_ids3)
        game_ids2 = ["00" + str(s) for s in game_ids2]
        game_ids = list(set(game_ids1).difference(game_ids2))
    except Exception as error:
        ic(error)
        game_ids = game_ids1
        dfr1 = pd.DataFrame()
        dfr2 = pd.DataFrame()
    return game_ids, dfr1, dfr2

def get_game_box(game_id,fun):
    stats = fun(game_id=game_id)
    df = stats.get_data_frames()
    return df

def get_games_box(game_ids, fun):
    df_ap1, df_ap2 = [], []
    t2=time.perf_counter()
    for game_id in tqdm(game_ids):
    # for game_id in game_ids:
        for attempt in range(5):
            try:
                t1 = time.perf_counter()
                df0 = get_game_box(game_id, fun)
                df1 = df0[1]
                df2 = df0[0]
                df_ap1.append(df1)
                df_ap2.append(df2)
                t2=time.perf_counter()
                tsleep = 0.8
                t3 = t2-t1
                if t3<tsleep:
                    time.sleep(tsleep-t3)
                break
            except Exception as error:
                if attempt == 0:
                    ic(game_id)
                    ic(error)
                # time.sleep(60)
                session = requests.Session()
                session.headers.update({
                    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:72.0) Gecko/20100101 Firefox/72.0'
                })
                NBAStatsHTTP.set_session(session)
                continue
    return df_ap1, df_ap2

# %%
for boxscore in boxscores[:1]:
    for year in range(2024,1995,-1):
        try:
            ic(year)          
            session = requests.Session()
            session.headers.update({
                'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:72.0) Gecko/20100101 Firefox/72.0'
            })
            NBAStatsHTTP.set_session(session)
            season = str(year)
            name = boxscore["name"]
            fun = boxscore["fun"]
            game_ids, dfr1, dfr2 = get_gameids(season, name)
            df_ap1, df_ap2 = get_games_box(game_ids, fun)
            df1 = pd.concat(df_ap1)
            df2 = pd.concat(df_ap2)
            df3 = pd.concat([dfr1, df1])
            # if name == "Trad":
            #     df3["gameId"] = df3["GAME_ID"]
            #     df3["MIN"] = df3["MIN"].astype("str")
            df3["gameId"] = df3["gameId"].astype(int)
            df3 = df3.sort_values(by=["gameId"]).reset_index(drop=True)
            df3.to_parquet(box_DIR + "NBA_Box_T_" + name + "_" + season + ".parquet")
            df4 = pd.concat([dfr2, df2])
            # if name == "Trad":
            #     df4["gameId"] = df4["GAME_ID"]
            #     df4["MIN"] = df4["MIN"].astype("str")
            df4["gameId"] = df4["gameId"].astype(int)
            df4 = df4.sort_values(by=["gameId"]).reset_index(drop=True)
            df4.to_parquet(box_DIR+ "NBA_Box_P_"+ name + "_"+ season+ ".parquet")
        except Exception as error:
            # time.sleep(60)
            ic(error)
            continue
# Out:
# ic| year: 2024| year: 2024
# ic| error: FileNotFoundError(2, 'No such file or directory')
#  66%|██████▌   | 602/909 [08:03<04:06,  1.25it/s]ic| game_id: '0022400605'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
# 100%|██████████| 909/909 [12:40<00:00,  1.20it/s]
# ic| year: 2023
# ic| error: FileNotFoundError(2, 'No such file or directory')
#  49%|████▉     | 602/1230 [08:15<08:23,  1.25it/s]ic| game_id: '0022300603'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
#  98%|█████████▊| 1204/1230 [16:53<00:21,  1.22it/s] ic| game_id: '0022301205'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
# 100%|██████████| 1230/1230 [17:46<00:00,  1.15it/s]
# ic| year: 2022
# ic| error: FileNotFoundError(2, 'No such file or directory')
#  49%|████▉     | 602/1230 [08:12<08:36,  1.22it/s]ic| game_id: '0022200603'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
#  98%|█████████▊| 1204/1230 [17:01<00:20,  1.24it/s] ic| game_id: '0022201205'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
# 100%|██████████| 1230/1230 [17:54<00:00,  1.14it/s]
# ic| year: 2021
# ic| error: FileNotFoundError(2, 'No such file or directory')
#  14%|█▍        | 170/1230 [02:17<14:17,  1.24it/s]ic| game_id: '0022100171'
# ic| error: AttributeError("'NoneType' object has no attribute 'keys'")
#  63%|██████▎   | 773/1230 [10:33<06:06,  1.25it/s]ic| game_id: '0022100774'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
# 100%|██████████| 1230/1230 [17:14<00:00,  1.19it/s]
# ic| year: 2020
# ic| error: FileNotFoundError(2, 'No such file or directory')
#  32%|███▏      | 350/1080 [04:43<09:45,  1.25it/s]ic| game_id: '0022000351'
# ic| error: JSONDecodeError('Expecting value: line 1 column 1 (char 0)')
#  88%|████████▊ | 952/1080 [13:05<01:42,  1.25it/s]ic| game_id: '0022000953'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
# 100%|██████████| 1080/1080 [15:23<00:00,  1.17it/s]
# ic| year: 2019
# ic| error: FileNotFoundError(2, 'No such file or directory')
#  57%|█████▋    | 602/1059 [08:15<06:06,  1.25it/s]ic| game_id: '0021900603'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
# 100%|██████████| 1059/1059 [15:10<00:00,  1.16it/s]
# ic| year: 2018
# ic| error: FileNotFoundError(2, 'No such file or directory')
#  49%|████▉     | 602/1230 [08:14<08:27,  1.24it/s]ic| game_id: '0021800603'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
#  98%|█████████▊| 1204/1230 [16:58<00:22,  1.14it/s] ic| game_id: '0021801205'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
# 100%|██████████| 1230/1230 [17:49<00:00,  1.15it/s]
# ic| year: 2017
# ic| error: FileNotFoundError(2, 'No such file or directory')
#  49%|████▉     | 602/1230 [08:20<08:23,  1.25it/s]ic| game_id: '0021700603'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
#  98%|█████████▊| 1204/1230 [17:07<00:21,  1.23it/s] ic| game_id: '0021701205'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
# 100%|██████████| 1230/1230 [17:58<00:00,  1.14it/s]
# ic| year: 2016
# ic| error: FileNotFoundError(2, 'No such file or directory')
#  49%|████▉     | 602/1230 [08:13<08:23,  1.25it/s]ic| game_id: '0021600603'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
#  98%|█████████▊| 1204/1230 [17:03<00:20,  1.25it/s] ic| game_id: '0021601205'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
# 100%|██████████| 1230/1230 [17:54<00:00,  1.14it/s]
# ic| year: 2015
# ic| error: FileNotFoundError(2, 'No such file or directory')
#  49%|████▉     | 602/1230 [08:23<08:23,  1.25it/s]ic| game_id: '0021500603'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
#  98%|█████████▊| 1204/1230 [17:11<00:21,  1.23it/s] ic| game_id: '0021501205'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
# 100%|██████████| 1230/1230 [18:01<00:00,  1.14it/s]
# ic| year: 2014
# ic| error: FileNotFoundError(2, 'No such file or directory')
#  49%|████▉     | 602/1230 [08:10<08:23,  1.25it/s]ic| game_id: '0021400603'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
#  98%|█████████▊| 1204/1230 [16:55<00:20,  1.25it/s] ic| game_id: '0021401205'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
# 100%|██████████| 1230/1230 [17:46<00:00,  1.15it/s]
# ic| year: 2013
# ic| error: FileNotFoundError(2, 'No such file or directory')
#  49%|████▉     | 602/1230 [08:20<08:23,  1.25it/s]ic| game_id: '0021300603'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
#  98%|█████████▊| 1204/1230 [17:06<00:20,  1.25it/s] ic| game_id: '0021301205'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
# 100%|██████████| 1230/1230 [17:58<00:00,  1.14it/s]
# ic| year: 2012
# ic| error: FileNotFoundError(2, 'No such file or directory')
#  49%|████▉     | 602/1230 [08:19<11:30,  1.10s/it]ic| game_id: '0021200603'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
#  98%|█████████▊| 1204/1230 [17:05<00:20,  1.25it/s] ic| game_id: '0021201205'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
#  99%|█████████▊| 1213/1230 [17:45<00:23,  1.41s/it]ic| game_id: '0021201214'
# ic| error: AttributeError("'NoneType' object has no attribute 'keys'")
# 100%|██████████| 1230/1230 [17:59<00:00,  1.14it/s]
# ic| year: 2011
# ic| error: FileNotFoundError(2, 'No such file or directory')
#  61%|██████    | 602/990 [08:18<05:11,  1.25it/s]ic| game_id: '0021100603'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
# 100%|██████████| 990/990 [14:03<00:00,  1.17it/s]
# ic| year: 2010
# ic| error: FileNotFoundError(2, 'No such file or directory')
#  49%|████▉     | 602/1230 [08:23<08:24,  1.24it/s]ic| game_id: '0021000603'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
#  98%|█████████▊| 1204/1230 [17:11<00:20,  1.25it/s] ic| game_id: '0021001205'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
# 100%|██████████| 1230/1230 [18:02<00:00,  1.14it/s]
# ic| year: 2009
# ic| error: FileNotFoundError(2, 'No such file or directory')
#  49%|████▉     | 602/1230 [08:22<08:24,  1.24it/s]ic| game_id: '0020900603'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
#  98%|█████████▊| 1204/1230 [17:14<00:21,  1.22it/s] ic| game_id: '0020901205'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
# 100%|██████████| 1230/1230 [18:05<00:00,  1.13it/s]
# ic| year: 2008
# ic| error: FileNotFoundError(2, 'No such file or directory')
#  49%|████▉     | 602/1230 [08:13<08:23,  1.25it/s]ic| game_id: '0020800603'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
#  98%|█████████▊| 1204/1230 [17:08<00:20,  1.24it/s] ic| game_id: '0020801205'
# ic| error: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)"))
# 100%|██████████| 1230/1230 [17:59<00:00,  1.14it/s]
# ic| year: 2007
# ic| error: FileNotFoundError(2, 'No such file or directory')
#   8%|▊         | 101/1230 [01:22<15:05,  1.25it/s]
